# %% [markdown]
# descrEVE_v2/
# │
# ├── data/                        # Onde ficam os dados (não comita no git se for grande)
# │   ├── raw/                     # Dados brutos (txt, csv, pdfs extraídos)
# │   ├── processed/               # Dados limpos e tokenizados
# │   └── models/                  # Onde salvaremos os arquivos .model (Word2Vec) e .pkl
# │
# ├── notebooks/                   # Para prototipagem visual e geração dos Dendrogramas
# │   ├── 01_exploracao.ipynb
# │   └── 02_dendrograma.ipynb     # Aqui geraremos os gráficos solicitados
# │
# ├── src/
# │   ├── __init__.py
# │   ├── config.py                # Gerenciamento de Configuração (.env e settings.yaml)
# │   │
# │   ├── pipeline/                # Módulos de Treinamento e Processamento (Offline)
# │   │   ├── __init__.py
# │   │   ├── preprocessor.py      # Limpeza, Tokenização (Spacy/Regex)
# │   │   └── trainer.py           # Treina Word2Vec e salva no disco
# │   │
# │   ├── engine/                  # Módulos de Inferência (Online/API)
# │   │   ├── __init__.py
# │   │   ├── semantic_search.py   # Carrega o modelo e faz a busca por cosseno
# │   │   └── bot_logic.py         # Lógica de negócio do Chatbot
# │   │
# │   └── api/                     # Interface HTTP (FastAPI)
# │       ├── main.py
# │       └── routes.py
# │
# ├── settings.yaml                # Suas configurações de domínio
# ├── .env                         # Senhas e credenciais
# └── requirements.txt             # Dependências limpas
